# %%
# %reset -f

# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np
import pandas as pd

# %%
file_dir = r'C:\D\Work\Unigroup\Apollo_Data\obstacle_demo\test'

file_nm_pic = list(map(str, list(range(100))))
for i in range(0,100):
    if i < 10:
        file_nm_pic[i] = '\\images\\00000' + file_nm_pic[i] + '.jpg'
    else:
        file_nm_pic[i] = '\\images\\0000' + file_nm_pic[i] + '.jpg'


file_nm_txt = list(map(str, list(range(100))))
for i in range(100):
    if i < 10:
        file_nm_txt[i] = '\\labels\\00000' + file_nm_txt[i] + '.txt'
    else:
        file_nm_txt[i] = '\\labels\\0000' + file_nm_txt[i] + '.txt'

# %%
# read image
for i in range(100):
    locals()['p' + str(i)] = mpimg.imread(file_dir+file_nm_pic[i])

# 图变量
dic_pic = list(globals().keys())
def is_pic(a):
    return str(a)[0] == 'p' and str(a)[1:].isdigit()

dic_pic = list(filter(is_pic, dic_pic))
#plt.imshow(eval(dic_pic[20]))
#plt.show()

# %%
# read labels
for i in range(100):
    locals()['data' + str(i)] = pd.read_table(file_dir+file_nm_txt[i],header=None, delim_whitespace=True)#, index_col=0)
#data98

# %%
frame_id = 0
plt.imshow(eval(dic_pic[frame_id]))
for i in range(eval('data'+str(frame_id)).shape[0] - 1):
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[4][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[5][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[7][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[6][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
plt.show()

# %%
frame_id = 1
plt.imshow(eval(dic_pic[frame_id]))
for i in range(eval('data'+str(frame_id)).shape[0] - 1):
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[4][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[5][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[7][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[6][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
plt.show()

# %%
frame_id = 2
plt.imshow(eval(dic_pic[frame_id]))
for i in range(eval('data'+str(frame_id)).shape[0] - 1):
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[4][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[5][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[4][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[7][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
    plt.plot([eval('data'+str(frame_id))[6][i+1],eval('data'+str(frame_id))[6][i+1]], [eval('data'+str(frame_id))[5][i+1],eval('data'+str(frame_id))[7][i+1]], color='blue')
plt.show()

# %%
# See all obstacles
for i in range(100):
     locals()['obs' + str(i)] = set(eval('data'+str(frame_id))[0])

obs = obs0
for i in range(1, 100):
    obs = obs | eval('obs'+str(i))
    
    
print(obs)
# Out:
# {'bus', 'truck', 'pedestrian', 'car', 'van', 'ignore'}
