# %%
reset -f

# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img_file = h5py.File(r'C:\D\Work\Unigroup\Apollo_Data\roadhacker_sample\image\667.h5','r')   #打开h5文件
arr_file = h5py.File(r'C:\D\Work\Unigroup\Apollo_Data\roadhacker_sample\attr\667.h5','r')

# %%
print(list(img.keys())[0:10])
print(list(arr.keys()))
# Out:
# ['1476238264.000', '1476238264.125', '1476238264.250', '1476238264.375', '1476238264.500', '1476238264.625', '1476238264.750', '1476238264.875', '1476238265.000', '1476238265.125']
# ['attrs']

# %%
a = img[list(img.keys())[0]]
a.shape
# Out:
# (320, 320, 3)

# %%
b = arr['attrs']
b.shape
# Out:
# (53270, 13)

# %%
plt.imshow(a)
plt.show()

# %%
list(b[0])
# Out:
# [1476238264.0,
#  -0.96499999809265136,
#  -11.773999962806702,
#  -0.00031784917015359899,
#  -0.00036500214624509162,
#  -0.00041215512233658421,
#  -0.00045930809842807685,
#  -0.00050646107451956949,
#  -0.00055361405061106212,
#  -0.18970288180163664,
#  -1.4762792472125739,
#  -174.20900001525879,
#  0.0]
